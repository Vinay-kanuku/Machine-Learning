# %%
import requests as rq
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib.animation import FuncAnimation

# %%
API_KEY = "QPG7IA8UCZ61ALJC"
COMPANY = "IBM"
URL = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={COMPANY}&interval=1min&apikey={API_KEY}"

# %%
def prepare_data(responce):
    stock_data = responce.json()['Time Series (1min)']
    stock_df = pd.DataFrame(stock_data).T
    stock_df.rename(columns={'4. close':'close'}, inplace=True)
    stock_df.index = pd.to_datetime(stock_df.index)
    stock_df['close'] = stock_df['close'].astype("float")
    return stock_df

# %%
def initilisation():
    line.set_data([], [])
    return line
 
def update(frame):
    x = stock_df.index[:frame]
    y = stock_df['close'][:frame]
    line.set_data(x, y)
    return line,

# %%
responce = rq.request("GET", URL)
stock_df = prepare_data(responce=responce)
fig, ax = plt.subplots(figsize=(10, 5))
ax.set_xlim(stock_df.index[0], stock_df.index[-1])  # Set x-axis range to match the data
ax.set_ylim(200, 240)  # Set y-axis range
line, = ax.plot([], [], color="blue", linewidth=2)

# Adding titles, labels, and grid to the axes
ax.set_title("Stock Price")
ax.set_xlabel("Time and Date")
ax.set_ylabel("Price (USD)")
plt.xticks(rotation=45)
ax.grid()

ani = FuncAnimation(fig, update, frames=len(stock_df), init_func=initilisation, blit=True, interval=100)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      12 plt.xticks(rotation=45)
#      13 ax.grid()
# ---> 15 ani = FuncAnimation(fig, update, frames=len(stock_df), init_func=initilisation, blit=True, interval=100)
#      16 plt.tight_layout()
#      17 plt.show()
#
# File ~\Downloads\anaconda\envs\myenv\Lib\site-packages\matplotlib\animation.py:1673, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1670 # Needs to be initialized so the draw functions work without checking
#    1671 self._save_seq = []
# -> 1673 super().__init__(fig, **kwargs)
#    1675 # Need to reset the saved seq, since right now it will contain data
#    1676 # for a single frame from init, which is not what we want.
#    1677 self._save_seq = []
#
# ...

# %%
# %matplotlib notebook

import requests as rq
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib.animation import FuncAnimation
import time 

API_KEY = "QPG7IA8UCZ61ALJC"
COMPANY = "IBM"
URL = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={COMPANY}&interval=1min&apikey={API_KEY}"

def prepare_data(responce):
    stock_data = responce.json()['Time Series (1min)']
    stock_df = pd.DataFrame(stock_data).T
    stock_df.rename(columns={'4. close':'close'}, inplace=True)
    stock_df.index = pd.to_datetime(stock_df.index)
    stock_df['close'] = stock_df['close'].astype("float")
    return stock_df

def initilisation():
    line.set_data([], [])
    return line,  # Correctly return a tuple

def update(frame):
    x = stock_df.index[:frame]
    y = stock_df['close'][:frame]
    line.set_data(x, y)
    return line,

# Fetch data and prepare DataFrame
 
response = rq.request("GET", URL)
response.json()
 
# stock_df = prepare_data(responce=response)

# # Set up the plot
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.set_xlim(stock_df.index[0], stock_df.index[-1])  # Set x-axis range to match the data
# ax.set_ylim(stock_df['close'].min() - 5, stock_df['close'].max() + 5)  # Adjust y-axis range
# line, = ax.plot([], [], color="blue", linewidth=2)

# # Adding titles, labels, and grid to the axes
# ax.set_title("Stock Price")
# ax.set_xlabel("Time and Date")
# ax.set_ylabel("Price (USD)")
# plt.xticks(rotation=45)
# ax.grid()
 
# # Create and display the animation
# # ani = FuncAnimation(fig, update, frames=len(stock_df), init_func=initilisation, blit=True, interval=100)
# # plt.tight_layout()

# # plt.show()
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
